# %%
import pandas as pd

df = pd.read_parquet("data/processed/foods_master.parquet")

df.head()
# Out:
#             food_id     food_name_en food_name_ar    food_group    meal_types  \
# 0  egy_5b14dcd94b29          almonds               Healthy Fats  Lunch|Dinner
# 1  egy_76c2436b593f           apples                     Fruits         Snack
# 2  egy_97648380db29         apricots                     Fruits         Snack
# 3  egy_bace40a1320f  apricots, dried                     Fruits         Snack
# 4  egy_c57a56bb0791       artichokes                 Vegetables  Lunch|Dinner
#
#   serving_name  serving_weight_g nutrition_basis  calories  protein  carbs  \
# 0        100 g             100.0        per_100g     640.0      9.3   15.1
# 1        100 g             100.0        per_100g      57.0      0.4   13.5
# 2        100 g             100.0        per_100g      58.0      0.9   12.7
# 3        100 g             100.0        per_100g     282.0      4.5   64.6
# 4        100 g             100.0        per_100g      45.0      3.5    7.4
#
# ...

# %%
df
# Out:
#                food_id                       food_name_en food_name_ar  \
# 0     egy_5b14dcd94b29                            almonds
# 1     egy_76c2436b593f                             apples
# 2     egy_97648380db29                           apricots
# 3     egy_bace40a1320f                    apricots, dried
# 4     egy_c57a56bb0791                         artichokes
# ..                 ...                                ...          ...
# 834  usda_596fb7a8df47       yogurt, greek, plain, nonfat
# 835  usda_dc151a7847a1   yogurt, greek, plain, whole milk
# 836  usda_6a1ef03a8cfb  yogurt, greek, strawberry, nonfat
# 837  usda_4fa28c373d56              yogurt, plain, nonfat
# 838  usda_166825a7c973          yogurt, plain, whole milk
#
#        food_group              meal_types serving_name  serving_weight_g  \
# 0    Healthy Fats            Lunch|Dinner        100 g             100.0
# 1          Fruits                   Snack        100 g             100.0
# ...

# %%
df.shape
# Out:
# (839, 17)

# %%
df.columns
# Out:
# Index(['food_id', 'food_name_en', 'food_name_ar', 'food_group', 'meal_types',
#        'serving_name', 'serving_weight_g', 'nutrition_basis', 'calories',
#        'protein', 'carbs', 'fat', 'fiber', 'diet_tags', 'allergens',
#        'is_composite_dish', 'source'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 839 entries, 0 to 838
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   food_id            839 non-null    object
#  1   food_name_en       839 non-null    object
#  2   food_name_ar       839 non-null    object
#  3   food_group         839 non-null    object
#  4   meal_types         839 non-null    object
#  5   serving_name       839 non-null    object
#  6   serving_weight_g   839 non-null    float64
#  7   nutrition_basis    839 non-null    object
#  8   calories           839 non-null    float64
#  9   protein            839 non-null    float64
#  10  carbs              839 non-null    float64
#  11  fat                839 non-null    float64
#  12  fiber              839 non-null    float64
#  13  diet_tags          839 non-null    object
#  14  allergens          839 non-null    object
#  15  is_composite_dish  839 non-null    bool
# ...

# %%
df.head(30)
# Out:
#              food_id                  food_name_en   food_name_ar  \
# 0   egy_5b14dcd94b29                       almonds
# 1   egy_76c2436b593f                        apples
# 2   egy_97648380db29                      apricots
# 3   egy_bace40a1320f               apricots, dried
# 4   egy_c57a56bb0791                    artichokes
# 5   egy_7e30fcde415c             artichokes, salad
# 6   egy_fdb7388828a7                       avocado
# 7   egy_a0a620f514d3                backing powder
# 8   egy_d13218f1b0f9                       bananas
# 9   egy_33edbb265388                barley, grains           شعير
# 10  egy_eb0fbdf8124a                  beans, broad
# 11  egy_336134b2a5b0         beans, broad (bisara)
# 12  egy_e7961a2674ef   beans, broad (foul), canned
# 13  egy_270a99ee3c40    beans, broad (foulmedames)
# 14  egy_41e7808b9cd2          beans, broad (green)
# 15  egy_c85bf2e06bae        beans, broad (menabet)
# ...

# %%
df.tail(20)
# Out:
#                food_id                                       food_name_en  \
# 819  usda_b1d943462b00          tomato, paste, canned, without salt added
# 820  usda_66bfdb3d8208                              tomato, puree, canned
# 821  usda_eaed46648ff6                                       tomato, roma
# 822  usda_39e99b9bc7a6             tomato, sauce, canned, with salt added
# 823  usda_3aec263ce758                 tomatoes, canned, red, ripe, diced
# 824  usda_861e2f7b8975                          tomatoes, crushed, canned
# 825  usda_3b590154b3f0                               tomatoes, grape, raw
# 826  usda_780828ff5c4c  tomatoes, whole, canned, solids and liquids, w...
# 827  usda_9ac324caf26a        tuna, ahi or yellowfin, frozen, wild caught
# 828  usda_3ef834058237  turkey, ground, 93% lean, 7% fat, pan-broiled ...
# 829  usda_637a5b3bcfc9              turkey, ground, 93% lean/ 7% fat, raw
# 830  usda_5a7587421c77                                       turnips, raw
# ...
